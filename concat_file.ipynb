# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.5.0-cp310-cp310-win_amd64.whl (10.4 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.4-py2.py3-none-any.whl (500 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.21.0
#   Using cached numpy-1.23.3-cp310-cp310-win_amd64.whl (14.6 MB)
# Requirement already satisfied: six>=1.5 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.3 pandas-1.5.0 pytz-2022.4

# %%
import pandas as pd

# %%
import os
import glob

# %%
path = r'C:\Users\inna_\OneDrive\Рабочий стол\DA2021\выгрузки'
all_files = glob.glob(os.path.join(path , "query-explorer-export*.tsv"))

# %%
li = []

# %%
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, sep="\t")
    li.append(df)

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#        ga:country                           ga:pagePath  \
# 0       Argentina                    hq.asodesk.com/ar/
# 1       Argentina                    hq.asodesk.com/ar/
# 2       Argentina                    hq.asodesk.com/ar/
# 3       Argentina                    hq.asodesk.com/ar/
# 4       Argentina                    hq.asodesk.com/ar/
# ...           ...                                   ...
# 592053     Russia          hq.asodesk.com/ru/top-charts
# 592054     Russia  hq.asodesk.com/settings/activity_log
# 592055     Russia  hq.asodesk.com/settings/activity_log
# 592056     Russia  hq.asodesk.com/settings/api-pricing/
# 592057     Russia  hq.asodesk.com/settings/api-pricing/
#
#                           ga:landingPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                            ga:secondPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                               ga:exitPagePath  \
# 0                                asodesk.com/
# 1                                asodesk.com/
# 2                          hq.asodesk.com/ar/
# 3                          hq.asodesk.com/ar/
# 4                          hq.asodesk.com/ar/
# ...                                       ...
# 592053  ru.asodesk.com/app-store-optimization
# 592054        hq.asodesk.com/settings/pricing
# 592055        hq.asodesk.com/settings/pricing
# 592056                        asodesk.com/api
# 592057                     hq.asodesk.com/ru/
#
#                                       ga:previousPagePath  ga:pageviews
# 0                                      hq.asodesk.com/ar/           7.0
# 1       hq.asodesk.com/ar/app/com.moni.android/monitoring           2.0
# 2                                              (entrance)           1.0
# 3                                      hq.asodesk.com/ar/           4.0
# 4       hq.asodesk.com/ar/app/com.moni.android/monitoring           1.0
# ...                                                   ...           ...
# 592053                                 ru.asodesk.com/api           1.0
# 592054                                 hq.asodesk.com/ru/           1.0
# 592055               hq.asodesk.com/settings/activity_log           1.0
# 592056               hq.asodesk.com/settings/api-pricing/           1.0
# 592057                                         (entrance)           4.0
#
# [592058 rows x 7 columns]

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592058 entries, 0 to 592057
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ga:country           592058 non-null  object
#  1   ga:pagePath          592058 non-null  object
#  2   ga:landingPagePath   592056 non-null  object
#  3   ga:secondPagePath    592056 non-null  object
#  4   ga:exitPagePath      592056 non-null  object
#  5   ga:previousPagePath  592055 non-null  object
#  6   ga:pageviews         592055 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 31.6+ MB

# %%
frame=frame.drop_duplicates(inplace=False)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428619 entries, 0 to 592057
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ga:country           428619 non-null  object
#  1   ga:pagePath          428619 non-null  object
#  2   ga:landingPagePath   428618 non-null  object
#  3   ga:secondPagePath    428618 non-null  object
#  4   ga:exitPagePath      428618 non-null  object
#  5   ga:previousPagePath  428617 non-null  object
#  6   ga:pageviews         428617 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 26.2+ MB

# %%
frame
# Out:
#          index ga:country                           ga:pagePath  \
# 0            0  Argentina                    hq.asodesk.com/ar/
# 1            1  Argentina                    hq.asodesk.com/ar/
# 2            2  Argentina                    hq.asodesk.com/ar/
# 3            3  Argentina                    hq.asodesk.com/ar/
# 4            4  Argentina                    hq.asodesk.com/ar/
# ...        ...        ...                                   ...
# 592053  592053     Russia          hq.asodesk.com/ru/top-charts
# 592054  592054     Russia  hq.asodesk.com/settings/activity_log
# 592055  592055     Russia  hq.asodesk.com/settings/activity_log
# 592056  592056     Russia  hq.asodesk.com/settings/api-pricing/
# 592057  592057     Russia  hq.asodesk.com/settings/api-pricing/
#
#                           ga:landingPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                            ga:secondPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                               ga:exitPagePath  \
# 0                                asodesk.com/
# 1                                asodesk.com/
# 2                          hq.asodesk.com/ar/
# 3                          hq.asodesk.com/ar/
# 4                          hq.asodesk.com/ar/
# ...                                       ...
# 592053  ru.asodesk.com/app-store-optimization
# 592054        hq.asodesk.com/settings/pricing
# 592055        hq.asodesk.com/settings/pricing
# 592056                        asodesk.com/api
# 592057                     hq.asodesk.com/ru/
#
#                                       ga:previousPagePath  ga:pageviews
# 0                                      hq.asodesk.com/ar/           7.0
# 1       hq.asodesk.com/ar/app/com.moni.android/monitoring           2.0
# 2                                              (entrance)           1.0
# 3                                      hq.asodesk.com/ar/           4.0
# 4       hq.asodesk.com/ar/app/com.moni.android/monitoring           1.0
# ...                                                   ...           ...
# 592053                                 ru.asodesk.com/api           1.0
# 592054                                 hq.asodesk.com/ru/           1.0
# 592055               hq.asodesk.com/settings/activity_log           1.0
# 592056               hq.asodesk.com/settings/api-pricing/           1.0
# 592057                                         (entrance)           4.0
#
# [592058 rows x 8 columns]

# %%
compression_opts = dict(method='zip',
                        archive_name='end_565001.csv')  
df.to_csv('end_565001.zip', index=False,
          compression=compression_opts)

# %%
frame.sort_values(by=['ga:country'],ascending=True)
# Out:
#        ga:country                                        ga:pagePath  \
# 62459   (not set)  ru.asodesk.com/blog/how-aso-specialists-can-co...
# 62328   (not set)                                 hq.asodesk.com/ru/
# 62327   (not set)                                 hq.asodesk.com/ru/
# 62326   (not set)                                 hq.asodesk.com/ru/
# 62325   (not set)                                 hq.asodesk.com/ru/
# ...           ...                                                ...
# 591030    Tunisia                hq.asodesk.com/accounts/signup/free
# 591031    Tunisia                                 hq.asodesk.com/us/
# 591032    Tunisia                                 hq.asodesk.com/us/
# 591010    Tunisia                                 hq.asodesk.com/us/
# 591009    Tunisia                                 hq.asodesk.com/us/
#
#                                        ga:landingPagePath  \
# 62459   ru.asodesk.com/blog/how-aso-specialists-can-co...
# 62328                                  hq.asodesk.com/ru/
# 62327                                  hq.asodesk.com/ru/
# 62326                                  hq.asodesk.com/ru/
# 62325                                  hq.asodesk.com/ru/
# ...                                                   ...
# 591030                        asodesk.com/email_course_ph
# 591031                        asodesk.com/email_course_ph
# 591032                        asodesk.com/email_course_ph
# 591010                                       asodesk.com/
# 591009                                       asodesk.com/
#
#                       ga:secondPagePath  \
# 62459                         (not set)
# 62328                hq.asodesk.com/ru/
# 62327                hq.asodesk.com/ru/
# 62326                hq.asodesk.com/ru/
# 62325                hq.asodesk.com/ru/
# ...                                 ...
# 591030  hq.asodesk.com/accounts/signup/
# 591031  hq.asodesk.com/accounts/signup/
# 591032  hq.asodesk.com/accounts/signup/
# 591010  hq.asodesk.com/accounts/signup/
# 591009  hq.asodesk.com/accounts/signup/
#
#                                           ga:exitPagePath  \
# 62459   ru.asodesk.com/blog/how-aso-specialists-can-co...
# 62328   hq.asodesk.com/ru/app/com.goplaytoday.shiftpri...
# 62327                                  hq.asodesk.com/ru/
# 62326                                  hq.asodesk.com/ru/
# 62325                                  hq.asodesk.com/ru/
# ...                                                   ...
# 591030                      asodesk.com/free-video-course
# 591031                      asodesk.com/free-video-course
# 591032                      asodesk.com/free-video-course
# 591010     hq.asodesk.com/tn/app/com.dev.fidness/crossing
# 591009     hq.asodesk.com/tn/app/com.dev.fidness/crossing
#
#                            ga:previousPagePath  ga:pageviews
# 62459                               (entrance)           1.0
# 62328                               (entrance)           1.0
# 62327                       hq.asodesk.com/ru/          19.0
# 62326           hq.asodesk.com/accounts/login/           1.0
# 62325                          asodesk.com/ru/           1.0
# ...                                        ...           ...
# 591030   hq.asodesk.com/accounts/choose-access           1.0
# 591031             asodesk.com/email_course_ph           1.0
# 591032         hq.asodesk.com/accounts/signup/           1.0
# 591010                      hq.asodesk.com/us/           5.0
# 591009  hq.asodesk.com/keyword-density-counter           1.0
#
# [428619 rows x 7 columns]

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.1-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from matplotlib) (21.3)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 1.5 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
#      -------------------------------------- 164.1/164.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from matplotlib) (1.23.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.4-py3-none-any.whl (960 kB)
#      -------------------------------------- 960.8/960.8 kB 3.4 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\inna_\onedrive\рабочий стол\da2021\ve\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.5 cycler-0.11.0 fonttools-4.37.4 kiwisolver-1.4.4 matplotlib-3.6.1 pillow-9.2.0
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df=frame.to_numpy()

# %%
print(frame)
# Out:
#        ga:country                           ga:pagePath  \
# 0       Argentina                    hq.asodesk.com/ar/
# 1       Argentina                    hq.asodesk.com/ar/
# 2       Argentina                    hq.asodesk.com/ar/
# 3       Argentina                    hq.asodesk.com/ar/
# 4       Argentina                    hq.asodesk.com/ar/
# ...           ...                                   ...
# 592053     Russia          hq.asodesk.com/ru/top-charts
# 592054     Russia  hq.asodesk.com/settings/activity_log
# 592055     Russia  hq.asodesk.com/settings/activity_log
# 592056     Russia  hq.asodesk.com/settings/api-pricing/
# 592057     Russia  hq.asodesk.com/settings/api-pricing/
#
#                           ga:landingPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                            ga:secondPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                               ga:exitPagePath  \
# 0                                asodesk.com/
# 1                                asodesk.com/
# 2                          hq.asodesk.com/ar/
# 3                          hq.asodesk.com/ar/
# 4                          hq.asodesk.com/ar/
# ...                                       ...
# 592053  ru.asodesk.com/app-store-optimization
# 592054        hq.asodesk.com/settings/pricing
# 592055        hq.asodesk.com/settings/pricing
# 592056                        asodesk.com/api
# 592057                     hq.asodesk.com/ru/
#
#                                       ga:previousPagePath  ga:pageviews
# 0                                      hq.asodesk.com/ar/           7.0
# 1       hq.asodesk.com/ar/app/com.moni.android/monitoring           2.0
# 2                                              (entrance)           1.0
# 3                                      hq.asodesk.com/ar/           4.0
# 4       hq.asodesk.com/ar/app/com.moni.android/monitoring           1.0
# ...                                                   ...           ...
# 592053                                 ru.asodesk.com/api           1.0
# 592054                                 hq.asodesk.com/ru/           1.0
# 592055               hq.asodesk.com/settings/activity_log           1.0
# 592056               hq.asodesk.com/settings/api-pricing/           1.0
# 592057                                         (entrance)           4.0
#
# [428619 rows x 7 columns]

# %%
my_series=frame.squeeze()

# %%
frame['index1'] = frame.index
# Out:
# C:\Users\inna_\AppData\Local\Temp\ipykernel_7900\1066673962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame['index1'] = frame.index

# %%
frame1=frame.copy()

# %%
frame1= frame1.reset_index(level=0)

# %%
frame1
# Out:
#          index ga:country                           ga:pagePath  \
# 0            0  Argentina                    hq.asodesk.com/ar/
# 1            1  Argentina                    hq.asodesk.com/ar/
# 2            2  Argentina                    hq.asodesk.com/ar/
# 3            3  Argentina                    hq.asodesk.com/ar/
# 4            4  Argentina                    hq.asodesk.com/ar/
# ...        ...        ...                                   ...
# 592053  592053     Russia          hq.asodesk.com/ru/top-charts
# 592054  592054     Russia  hq.asodesk.com/settings/activity_log
# 592055  592055     Russia  hq.asodesk.com/settings/activity_log
# 592056  592056     Russia  hq.asodesk.com/settings/api-pricing/
# 592057  592057     Russia  hq.asodesk.com/settings/api-pricing/
#
#                           ga:landingPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                            ga:secondPagePath  \
# 0                         hq.asodesk.com/ar/
# 1                         hq.asodesk.com/ar/
# 2                         hq.asodesk.com/ar/
# 3                         hq.asodesk.com/ar/
# 4                         hq.asodesk.com/ar/
# ...                                      ...
# 592053  hq.asodesk.com/settings/api-pricing/
# 592054  hq.asodesk.com/settings/api-pricing/
# 592055  hq.asodesk.com/settings/api-pricing/
# 592056  hq.asodesk.com/settings/api-pricing/
# 592057  hq.asodesk.com/settings/api-pricing/
#
#                               ga:exitPagePath  \
# 0                                asodesk.com/
# 1                                asodesk.com/
# 2                          hq.asodesk.com/ar/
# 3                          hq.asodesk.com/ar/
# 4                          hq.asodesk.com/ar/
# ...                                       ...
# 592053  ru.asodesk.com/app-store-optimization
# 592054        hq.asodesk.com/settings/pricing
# 592055        hq.asodesk.com/settings/pricing
# 592056                        asodesk.com/api
# 592057                     hq.asodesk.com/ru/
#
#                                       ga:previousPagePath  ga:pageviews
# 0                                      hq.asodesk.com/ar/           7.0
# 1       hq.asodesk.com/ar/app/com.moni.android/monitoring           2.0
# 2                                              (entrance)           1.0
# 3                                      hq.asodesk.com/ar/           4.0
# 4       hq.asodesk.com/ar/app/com.moni.android/monitoring           1.0
# ...                                                   ...           ...
# 592053                                 ru.asodesk.com/api           1.0
# 592054                                 hq.asodesk.com/ru/           1.0
# 592055               hq.asodesk.com/settings/activity_log           1.0
# 592056               hq.asodesk.com/settings/api-pricing/           1.0
# 592057                                         (entrance)           4.0
#
# [592058 rows x 8 columns]

# %%
index=frame1['index']
index
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 592053    592053
# 592054    592054
# 592055    592055
# 592056    592056
# 592057    592057
# Name: index, Length: 592058, dtype: int64

# %%
index=pd.DataFrame(data=index)

# %%
from pathlib import Path

# %%
filepath2 = Path('выгрузки/out.csv')

# %%
filepath2.parent.mkdir(parents=True, exist_ok=True)  
index.to_csv(filepath2, index= False)
